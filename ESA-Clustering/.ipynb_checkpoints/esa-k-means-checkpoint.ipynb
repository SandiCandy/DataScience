# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
plt.rcParams['figure.figsize'] = (16, 9)

# Creating a sample dataset with 4 clusters
url = '/Users/sandra/Desktop/DataScience2020/ESA-Clustering/edlich-kmeans-A0.csv'
df = pd.read_csv(url)
df
#X, y = make_blobs(n_samples=800, n_features=3, centers=4)
# Out:
#           V1         V2         V3
# 0  -5.340236   4.747246   3.823326
# 1  -9.587065  -3.434466   9.701839
# 2  -8.385012  -3.902794   8.514620
# 3   5.708226   2.658575   5.404482
# 4  -7.431665  -4.390251   9.003216
# ..       ...        ...        ...
# 95  5.240474   2.983800   5.104915
# 96 -1.675543   3.780111  -8.060940
# 97  2.979751  10.772783 -10.093143
# 98 -5.154519   5.976515   2.794622
# 99 -4.878509   5.096635   5.659783
#
# [100 rows x 3 columns]

# %%
f1 = df['V1']
f2 = df['V2']
f3 = df['V3']
X = f1, f2, f3
y = np.array(list(f3))
#Plot
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(f1, f2, f3)

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=4)
# Fitting with inputs
kmeans = kmeans.fit(df)
# Predicting the clusters
labels = kmeans.predict(df)
# Getting the cluster centers
C = kmeans.cluster_centers_
fig = plt.figure()
ax = Axes3D(fig)
#ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
ax.scatter(f1, f2, f3, c=y)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=1000)

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=5)
# Fitting with inputs
kmeans = kmeans.fit(df)
# Predicting the clusters
labels = kmeans.predict(df)
# Getting the cluster centers
C = kmeans.cluster_centers_
fig = plt.figure()
ax = Axes3D(fig)
#ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
ax.scatter(f1, f2, f3, c=y)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=1000)

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=6)
# Fitting with inputs
kmeans = kmeans.fit(df)
# Predicting the clusters
labels = kmeans.predict(df)
# Getting the cluster centers
C = kmeans.cluster_centers_
fig = plt.figure()
ax = Axes3D(fig)
#ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y)
ax.scatter(f1, f2, f3, c=y)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c='#050505', s=1000)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(df)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ## k = 5 ist gut --> Ausgeben der Daten für k=5

# %%
# Initializing KMeans
kmeans = KMeans(n_clusters=5)
# Fitting with inputs
kmeans = kmeans.fit(df)
# Predicting the clusters
labels = kmeans.predict(df)
#Auswertung
clusters = {}
n = 0
for item in labels:
    if item in clusters:
        clusters[item].append(df[n:(n+1)])
    else:
        clusters[item] = [df[n:(n+1)]]
    n +=1
clusters
# Out:
# {1: [         V1        V2        V3
#   0 -5.340236  4.747246  3.823326,
#             V1       V2        V3
#   14 -5.179535  4.84632  4.247216,
#             V1        V2       V3
#   18 -4.428477  6.656869  4.00896,
#             V1        V2        V3
#   19 -4.916626  4.527063  3.459854,
#             V1        V2        V3
#   22 -5.185757  7.628383  4.348733,
#             V1        V2        V3
#   35 -4.540142  5.813017  2.734613,
#             V1        V2        V3
#   37 -5.972634  6.729571  4.244065,
#             V1        V2        V3
#   43 -3.692976  6.049123  3.020887,
#             V1        V2        V3
#   56 -4.365004  6.980472  4.190393,
#             V1        V2        V3
#   61 -5.215827  4.258524  3.990111,
#             V1        V2        V3
#   66 -5.054178  5.740377  3.168962,
#            V1        V2        V3
#   67 -4.26072  6.517735  2.900084,
#             V1        V2        V3
#   68 -5.458652  4.057271  1.873968,
# ...
